# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pickle
# Ouvrir des données stockées dans un fichier .pk data = pickle.load(open('data.pk','rb'), encoding='latin1')
# Charger par exemple la matrice H H = data.get('H')
# Sauvegarder des données dans un fichier .pk pickle.dump({'obj1': obj1, 'obj2':obj2}, open('filename.pk','wb'), pickle.HIGHEST_PROTOCOL)

# %%
data = pickle.load(open('data.pk','rb'), encoding='latin1')
ori = data.get('original')
obs = data.get('observations')
filter = data.get('filter')
H = data.get('H')
T = data.get('T')
# pickle.dump({'H': H, 'obj2':obj2}, open('data.pk','wb'), pickle.HIGHEST_PROTOCOL)

# %%
obs

# %%
plt.figure()
plt.imshow(ori,cmap='gray')
plt.figure()
plt.imshow(obs,cmap='gray')
plt.show()
